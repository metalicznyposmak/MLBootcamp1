# %% [markdown]
# <a href="https://colab.research.google.com/github/metalicznyposmak/MLBootcamp1/blob/main/supervised/01_basics/03_feature_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn

sklearn.__version__
# Out:
# '1.6.1'

# %%
def fetch_financial_data(company='AMZN'):
  """
  This function fetches stock market quotations.
  """
  import pandas_datareader.data as web
  return web.DataReader(name=company, data_source='stooq')

df_raw = fetch_financial_data()
df_raw.head()
# Out:
#               Open    High       Low   Close    Volume
# Date
# 2025-10-21  218.43  223.32  217.9900  222.03  50494565
# 2025-10-20  213.88  216.69  213.5900  216.48  38882819
# 2025-10-17  214.56  214.80  211.0300  213.04  45986944
# 2025-10-16  215.67  218.59  212.8101  214.47  42414591
# 2025-10-15  216.62  217.71  212.6600  215.57  45909469

# %%
df = df_raw.copy()
df = df[:5]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2025-10-21 to 2025-10-15
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5 non-null      float64
#  1   High    5 non-null      float64
#  2   Low     5 non-null      float64
#  3   Close   5 non-null      float64
#  4   Volume  5 non-null      int64
# dtypes: float64(4), int64(1)
# memory usage: 240.0 bytes

# %%
df['Volume'] = df['Volume'].astype(float)
df
# Out:
#               Open    High       Low   Close      Volume
# Date
# 2025-10-21  218.43  223.32  217.9900  222.03  50494565.0
# 2025-10-20  213.88  216.69  213.5900  216.48  38882819.0
# 2025-10-17  214.56  214.80  211.0300  213.04  45986944.0
# 2025-10-16  215.67  218.59  212.8101  214.47  42414591.0
# 2025-10-15  216.62  217.71  212.6600  215.57  45909469.0

# %% [markdown]
# # Generowanie nowych zmiennych

# %%
df.index.day
# Out:
# Index([21, 20, 17, 16, 15], dtype='int32', name='Date')

# %%
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year
df
# Out:
#               Open    High       Low   Close      Volume  day  month  year
# Date
# 2025-10-21  218.43  223.32  217.9900  222.03  50494565.0   21     10  2025
# 2025-10-20  213.88  216.69  213.5900  216.48  38882819.0   20     10  2025
# 2025-10-17  214.56  214.80  211.0300  213.04  45986944.0   17     10  2025
# 2025-10-16  215.67  218.59  212.8101  214.47  42414591.0   16     10  2025
# 2025-10-15  216.62  217.71  212.6600  215.57  45909469.0   15     10  2025

# %% [markdown]
# # Dyskretyzacja zmiennej ciąglej

# %%
df = pd.DataFrame(data={'height': [175., 178.5, 185., 191., 184.5, 183., 168.]})
df
# Out:
#    height
# 0   175.0
# 1   178.5
# 2   185.0
# 3   191.0
# 4   184.5
# 5   183.0
# 6   168.0

# %%
df['height_cat'] = pd.cut(x=df.height, bins=3)
df
# Out:
#    height          height_cat
# 0   175.0  (167.977, 175.667]
# 1   178.5  (175.667, 183.333]
# 2   185.0    (183.333, 191.0]
# 3   191.0    (183.333, 191.0]
# 4   184.5    (183.333, 191.0]
# 5   183.0  (175.667, 183.333]
# 6   168.0  (167.977, 175.667]

# %%
df['height_cat'] = pd.cut(x=df.height, bins=(160, 175, 180, 195))
df
# Out:
#    height  height_cat
# 0   175.0  (160, 175]
# 1   178.5  (175, 180]
# 2   185.0  (180, 195]
# 3   191.0  (180, 195]
# 4   184.5  (180, 195]
# 5   183.0  (180, 195]
# 6   168.0  (160, 175]

# %%
df['height_cat'] = pd.cut(x=df.height, bins=(160, 175, 180, 195), labels=['small', 'medium', 'high'])
df
# Out:
#    height height_cat
# 0   175.0      small
# 1   178.5     medium
# 2   185.0       high
# 3   191.0       high
# 4   184.5       high
# 5   183.0       high
# 6   168.0      small

# %%
pd.get_dummies(df, drop_first=True, prefix='height').astype(int)
# Out:
#    height  height_medium  height_high
# 0     175              0            0
# 1     178              1            0
# 2     185              0            1
# 3     191              0            1
# 4     184              0            1
# 5     183              0            1
# 6     168              0            0

# %% [markdown]
# # Ekstrakcja cech

# %%
df = pd.DataFrame(data={'lang': [['PL', 'END'], ['GER', 'ENG', 'PL', 'FRA'], ['RUS']]})
df
# Out:
#                   lang
# 0            [PL, END]
# 1  [GER, ENG, PL, FRA]
# 2                [RUS]

# %%
df['lang_number'] = df['lang'].apply(len)
df
# Out:
#                   lang  lang_number
# 0            [PL, END]            2
# 1  [GER, ENG, PL, FRA]            4
# 2                [RUS]            1

# %%
df['PL_flag'] = df['lang'].apply(lambda x: 1 if 'PL' in x else 0)
df
# Out:
#                   lang  lang_number  PL_flag
# 0            [PL, END]            2        1
# 1  [GER, ENG, PL, FRA]            4        1
# 2                [RUS]            1        0

# %%
df =pd.DataFrame(data={'website': ['wp.pl', 'onet.pl', 'google.com']})
df
# Out:
#       website
# 0       wp.pl
# 1     onet.pl
# 2  google.com

# %%
df.website.str.split('.', expand=True)
# Out:
#         0    1
# 0      wp   pl
# 1    onet   pl
# 2  google  com

# %%
new = df.website.str.split('.', expand=True)
df['portal'] = new[0]
df['extension'] = new[1]
df
# Out:
#       website  portal extension  number
# 0       wp.pl      wp        pl       0
# 1     onet.pl    onet        pl       0
# 2  google.com  google       com       0
